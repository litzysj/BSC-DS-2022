# %% [markdown]
# # APIs - Gathering Data Using Requests

# %% [markdown]
# ## The Many Use Cases For APIs
#
# APIs can be used for many things - much more than just retrieving information. Twilio has an API that allows you to write a script to send text messages to people. GitHub has an API for creating new repositories. Many services have APIs allowing computers to automate tasks that a person might otherwise have to do through a website - whether uploading a photo to Flickr, searching for a company name in a state database, or getting a list of garbage collection times for a municipality.

# %% [markdown]
# ## Limitations of APIs
#
# When working with APIs, there are some limitations you have to be aware of - especially relating to scope and scale.
#
# * **Scope** - Just because a company has an API and has information, it doesn't mean you can get all of the information you might want through their API
#
# * **Scale** - Some APIs are provided for free as a public service. Others you have to pay for, or allow you to perform activities (like sending a text message) that you pay for. Make sure that you know what the rate limits are and that your use case isn't going to need more API calls than you will be able to make.
#
# What else is good to know? **Every API is different!** There are some standards out there in terms of documentation and usage... but it's like the wild west - rapid expansion with few rules.
#
# With all that out of the way - Let's take a look at the `requests` library and its uses.

# %% [markdown]
# ### "Requests is the only Non-GMO HTTP library for Python, safe for human consumption."
#
# > "Requests allows you to send organic, grass-fed HTTP/1.1 requests, without the need for manual labor."
#
# Straight from the `requests` [documentation](https://pypi.org/project/requests/)

# %% [markdown]
# ### Types of Requests
#
# We will mostly use GET requests in order to get data, but there are other options.
#
# ![CRUD image from IntelliPaat](https://intellipaat.com/mediaFiles/2015/08/MongoDB-CRUD-operations.jpg)
#
# That's right - CRUD summarizes the kinds of requests you can make with most APIs.
#
# Let's say you are looking at an API for a car rental company like Hertz or Zipcar - the following different requests could generate these different responses:
#
# | Request               | Result                               | In CRUD Terms |
# | --------------------- | ------------------------------------ | ------------- |
# | GET /stores/          | User sees the list of stores         | Read          |
# | GET /rentals/         | User sees the history of car rentals | Read          |
# | POST /rentals/        | User rents a car                     | Create        |
# | PUT /rentals/{id}/    | User changes destination store       | Update        |
# | DELETE /rentals/{id}/ | User cancels the active car rental   | Delete        |

# %% [markdown]
# ### Let's get started!

# %%
import requests

# %%
# Don't already have the library? Uncomment the below code and install it locally
#!pip install requests

# %%
# Create a GET request, then check the type of object
#Structure of request 
r = requests.get('https://api.github.com/events') 
type(r)
# Out:
# requests.models.Response

# %%
# So what does this look like?
r.text
# Out:
# '[{"id":"22183786963","type":"PushEvent","actor":{"id":38507638,"login":"rmconsole5-wk","display_login":"rmconsole5-wk","gravatar_id":"","url":"https://api.github.com/users/rmconsole5-wk","avatar_url":"https://avatars.githubusercontent.com/u/38507638?"},"repo":{"id":243430149,"name":"Workiva/flip-tables","url":"https://api.github.com/repos/Workiva/flip-tables"},"payload":{"push_id":10083794405,"size":29,"distinct_size":1,"ref":"refs/heads/master","head":"4a41f96c2d20f7430b71ecae3ef4d8bf52a3007e","before":"50acc656bdad14df3dff96ad8a5f6c27000288a0","commits":[{"sha":"806d7a39933a5833ee76386f285ea76c543f3c82","author":{"email":"brian@onecloud.io","name":"Brian Meyers"},"message":"Merge tag \'fliptables-1.1.2-onecloud\' into develop\\n\\nRelease fliptables-1.1.2-onecloud","distinct":false,"url":"https://api.github.com/repos/Workiva/flip-tables/commits/806d7a39933a5833ee76386f285ea76c543f3c82"},{"sha":"370eb96be7ea934dfa256a585d20f91df84d096b","author":{"email":"andrew.underwood@workiva.com","name":"Andrew Underwood"},"message":"Fix gradle","distinct":false,"url":"https://api.github.com/repos/Workiva/flip-tables/commits/370eb96be7ea934dfa256a585d20f91df84d096b"},{"sha":"2a61098d7152eec9801e377834fa3b68cebf757d","author":{"email":"andrew.underwood@workiva.com","name":"Andrew Underwood"},"message":"Add PR template","distinct":false,"url":"https://api.github.com/repos/Workiva/flip-tables/commits/2a61098d7152eec9801e377834fa3b68cebf757d"},{"sha":"6344380a997457abdbae862b4c751c25ada1e78b","author":{"email":"andrew.underwood@workiva.com","name":"Andrew Underwood"},"message":"Add WK Build Dockerfile","distinct":false,"url":"https://api.github.com/repos/Workiva/flip-tables/commits/6344380a997457abdbae862b4c751c25ada1e78b"},{"sha":"501a102400af4c5149b684fab87f15f9c163bd0d","author":{"email":"andrew.underwood@workiva.com","name":"Andrew Underwood"},"message":"Fix CVE in junit","distinct":false,"url":"https://api.github.com/repos/Workiva/flip-tables/commits/501a102400af4c5149b684fab87f15f9c163bd0d"},{"sha":"332f6811ae110d940b8741d994976dcacb1ea800","author":{"email":"andrew.underwood@workiva.com","name":"Andrew Underwood"},"message":"Fix junit cve","distinct":false,"url":"https://api.github.com/repos/Workiva/flip-tables/commits/332f6811ae110d940b8741d994976dcacb1ea800"},{"sha":"28f7fa6ef638f081d81fcf04e98c23a53d02ccc3","author":{"email":"andrew.underwood@workiva.com","name":"Andrew Underwood"},"message":"Add dependabot","distinct":false,"url":"https://api.github.com/repos/Workiva/flip-tables/commits/28f7fa6ef638f081d81fcf04e98c23a53d02ccc3"},{"sha":"f4154d9b0a3cf45e23211ca42d8a4bae9d3da268","author":{"email":"andrew.underwood@workiva.com","name":"Andrew Underwood"},"message":"End Dockerfile in scratch","distinct":false,"url":"https://api.github.com/repos/Workiva/flip-tables/commits/f4154d9b0a3cf45e23211ca42d8a4bae9d3da268"},{"sha":"2288c65ec98e7fc3c6ea0655eb3ca824ec318a58","author":{"email":"andrew.underwood@workiva.com","name":"Andrew Underwood"},"message":"Only assemble jar in Build, don\'t run tests","distinct":false,"url":"https://api.github.com/repos/Workiva/flip-tables/commits/2288c65ec98e7fc3c6ea0655eb3ca824ec318a58"},{"sha":"634860ab8f66509a80f37c65f7c70a046f684327","author":{"email":"andrew.underwood@workiva.com","name":"Andrew Underwood"},"message":"Simplify Grade config","distinct":false,"url":"https://api.github.com/repos/Workiva/flip-tables/commits/634860ab8f66509a80f37c65f7c70a046f684327"},{"sha":"9041dd8966d059580415d464d8f9c9e7a8b93a34","author":{"email":"andrew.underwood@workiva.com","name":"Andrew Underwood"},"message":"Add skynet.yaml","distinct":false,"url":"https://api.github.com/repos/Workiva/flip-tables/commits/9041dd8966d059580415d464d8f9c9e7a8b93a34"},{"sha":"f0a01f2380e43abbb4c1a87a0fb8f421846ab6a6","author":{"email":"andrew.underwood@workiva.com","name":"Andrew Underwood"},"message":"Fix skynet.yaml","distinct":false,"url":"https://api.github.com/repos/Workiva/flip-tables/commits/f0a01f2380e43abbb4c1a87a0fb8f421846a ...

# %% [markdown]
# ![Oh good heavens gif, from gfycat](https://thumbs.gfycat.com/ColdAmbitiousDogwoodtwigborer-size_restricted.gif)

# %% [markdown]
# Obviously you're never going to just scan that quickly for any data you need, we need to wrangle that response to make it usable.
#
# But first, let's look at some of the other attributes of `requests.models.Response` objects.
#
# We can check out all of the attributes [here](https://2.python-requests.org//en/v0.10.6/api/) in the documentation.

# %%
# Another attribute, what does this show us?
# Gives you the meta data
r.headers
# Out:
# {'Server': 'GitHub.com', 'Date': 'Mon, 06 Jun 2022 15:42:29 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'public, max-age=60, s-maxage=60', 'Vary': 'Accept, Accept-Encoding, Accept, X-Requested-With', 'ETag': 'W/"09b983b10197b65461203e4fcfe05715e73f165f7f2436d8f4466ee8d11ee987"', 'Last-Modified': 'Mon, 06 Jun 2022 15:37:29 GMT', 'X-Poll-Interval': '60', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Link': '<https://api.github.com/events?page=2>; rel="next", <https://api.github.com/events?page=10>; rel="last"', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '0', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'Content-Encoding': 'gzip', 'X-RateLimit-Limit': '60', 'X-RateLimit-Remaining': '59', 'X-RateLimit-Reset': '1654533749', 'X-RateLimit-Resource': 'core', 'X-RateLimit-Used': '1', 'Accept-Ranges': 'bytes', 'Transfer-Encoding': 'chunked', 'X-GitHub-Request-Id': 'CC27:970A:1CB40D6:583FC1C:629E2065'}

# %% [markdown]
# ### Checking out the status of your request

# %%
# Another attribute
r.status_code

# %%
# http.dog
# http.cat
# Describes types of status codes

# %% [markdown]
# ### [Types of status codes](https://http.cat/)
#
# 1xx - Informational responses
#
# 2xx - Success
# - 200 OK
# - 201 Created
# - 204 No Content
#
# 3xx - Redirection
#
# - 301 Moved Permanently (permanent URL redirection)
# - 304 Not Modified (A conditional GET or HEAD request has been received and would have resulted in a 200 OK response if it were not for the fact that the condition evaluated to false.)
#
# 4xx - Client errors
#
# - 400 Bad Request
# - 401 Unauthorized
# - 403 Forbidden
# - 404 Not Found
#
# 5xx - Server errors
#
# - 500 Internal Server Error

# %%
# Get status code for a "broken" link

r_broken = requests.get('https://api.github.com/fake-ending')
r_broken.status_code
# Out:
# 404

# %% [markdown]
# Can also explictly ask for the returned format to be json as a method.

# %% [markdown]
# #### A note on errors and exceptions with the Requests library
#
# There are a number of exceptions and error codes you need to be familiar with when using the Requests library in Python.
#
# - The Requests library will raise a ConnectionError exception if there is a network problem like a DNS failure, or refused connection
# - These are rare, but with invalid HTTP responses, Requests will also raise an HTTPError exception
# - A Timeout exception will be raised if a request times out
# - If and when a request exceeds the preconfigured number of maximum redirections, then a TooManyRedirects exception will be raised

# %%
# Going back to our working request - how does this look, compared to text?
r.json()
# Out:
# [{'id': '22183786963',
#   'type': 'PushEvent',
#   'actor': {'id': 38507638,
#    'login': 'rmconsole5-wk',
#    'display_login': 'rmconsole5-wk',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rmconsole5-wk',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/38507638?'},
#   'repo': {'id': 243430149,
#    'name': 'Workiva/flip-tables',
#    'url': 'https://api.github.com/repos/Workiva/flip-tables'},
#   'payload': {'push_id': 10083794405,
#    'size': 29,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '4a41f96c2d20f7430b71ecae3ef4d8bf52a3007e',
#    'before': '50acc656bdad14df3dff96ad8a5f6c27000288a0',
#    'commits': [{'sha': '806d7a39933a5833ee76386f285ea76c543f3c82',
#      'author': {'email': 'brian@onecloud.io', 'name': 'Brian Meyers'},
#      'message': "Merge tag 'fliptables-1.1.2-onecloud' into develop\n\nRelease fliptables-1.1.2-onecloud",
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Workiva/flip-tables/commits/806d7a39933a5833ee76386f285ea76c543f3c82'},
#     {'sha': '370eb96be7ea934dfa256a585d20f91df84d096b',
#      'author': {'email': 'andrew.underwood@workiva.com',
#       'name': 'Andrew Underwood'},
#      'message': 'Fix gradle',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Workiva/flip-tables/commits/370eb96be7ea934dfa256a585d20f91df84d096b'},
#     {'sha': '2a61098d7152eec9801e377834fa3b68cebf757d',
#      'author': {'email': 'andrew.underwood@workiva.com',
#       'name': 'Andrew Underwood'},
#      'message': 'Add PR template',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Workiva/flip-tables/commits/2a61098d7152eec9801e377834fa3b68cebf757d'},
#     {'sha': '6344380a997457abdbae862b4c751c25ada1e78b',
#      'author': {'email': 'andrew.underwood@workiva.com',
#       'name': 'Andrew Underwood'},
#      'message': 'Add WK Build Dockerfile',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Workiva/flip-tables/commits/6344380a997457abdbae862b4c751c25ada1e78b'},
#     {'sha': '501a102400af4c5149b684fab87f15f9c163bd0d',
#      'author': {'email': 'andrew.underwood@workiva.com',
#       'name': 'Andrew Underwood'},
#      'message': 'Fix CVE in junit',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Workiva/flip-tables/commits/501a102400af4c5149b684fab87f15f9c163bd0d'},
#     {'sha': '332f6811ae110d940b8741d994976dcacb1ea800',
#      'author': {'email': 'andrew.underwood@workiva.com',
#       'name': 'Andrew Underwood'},
#      'message': 'Fix junit cve',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Workiva/flip-tables/commits/332f6811ae110d940b8741d994976dcacb1ea800'},
#     {'sha': '28f7fa6ef638f081d81fcf04e98c23a53d02ccc3',
#      'author': {'email': 'andrew.underwood@workiva.com',
#       'name': 'Andrew Underwood'},
#      'message': 'Add dependabot',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Workiva/flip-tables/commits/28f7fa6ef638f081d81fcf04e98c23a53d02ccc3'},
#     {'sha': 'f4154d9b0a3cf45e23211ca42d8a4bae9d3da268',
#      'author': {'email': 'andrew.underwood@workiva.com',
#       'name': 'Andrew Underwood'},
#      'message': 'End Dockerfile in scratch',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Workiva/flip-tables/commits/f4154d9b0a3cf45e23211ca42d8a4bae9d3da268'},
#     {'sha': '2288c65ec98e7fc3c6ea0655eb3ca824ec318a58',
#      'author': {'email': 'andrew.underwood@workiva.com',
#       'name': 'Andrew Underwood'},
#      'message': "Only assemble jar in Build, don't run tests",
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Workiva/flip-tables/commits/2288c65ec98e7fc3c6ea0655eb3ca824ec318a58'},
#     {'sha': '634860ab8f66509a80f37c65f7c70a046f684327',
#      'author': {'email': 'andrew.underwood@workiva.com',
#       'name': 'Andrew Underwood'},
#      'message': 'Simplify Grade config',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Workiva/flip-tables/commits/634860ab8f66509a80f37c65f7c70a046f684327'},
#     {'sha': '9041dd8966d059580415d464d8f9c9e7a8b93a34',
#      'author': {'email': 'andrew.underwood@workiva.com',
#       'name': 'Andrew Underwood'},
#      'message': 'Add skynet.yaml',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Workiva/flip-tables/commits/9041dd8966d059580415d464d8f9c9e7a8b93a34'},
#     {'sha': 'f0a01f2380e43abbb4c1a87a0fb8f421846ab6a6',
#      'author': {'email': 'andrew.underwood@workiva.com',
#       'name': 'Andrew Underwood'},
#      'message': 'Fix skynet.yaml',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Workiva/flip-tables/commits/f0a01f2380e43abbb4c1a87a0fb8f421846ab6a6'},
#     {'sha': 'bf142420249a98e6d2e08392b50232cbd5b46fa0',
#      'author': {'email': 'andrew.underwood@workiva.com',
#       'name': 'Andrew Underwood'},
#      'message': 'Add skynet.yaml contact',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Workiva/flip-tables/commits/bf142420249a98e6d2e08392b50232cbd5b46fa0'},
#     {'sha': 'c8023abf735346e71dd1e1545d0dbfdc96e607e3',
#      'author': {'email': 'andrew.underwood@workiva.com',
#       'name': 'Andrew Underwood'},
#      'message': 'Dont comment out skynet contact',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Workiva/flip-tables/commits/c8023abf735346e71dd1e1545d0dbfdc96e607e3'},
#     {'sha': 'f0c0741b381ec753ff04ce502aaec05b8a81fa3e',
#      'author': {'email': 'andrew.underwood@workiva.com',
#       'name': 'Andrew Underwood'},
#      'message': 'Better skynet docs link',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Workiva/flip-tables/commits/f0c0741b381ec753ff04ce502aaec05b8a81fa3e'},
#     {'sha': 'e0d060ed1cf221d3111fd785629af55f06cc26eb',
#      'author': {'email': 'andrew.underwood@workiva.com',
#       'name': 'Andrew Underwood'},
#      'message': 'Include pom in published jar',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Workiva/flip-tables/commits/e0d060ed1cf221d3111fd785629af55f06cc26eb'},
#     {'sha': '58a55da60cd7564d8ee481bde908ea0166d435eb',
#      'author': {'email': 'andrew.underwood@workiva.com',
#       'name': 'Andrew Underwood'},
#      'message': 'CI friendly gradle logging',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Workiva/flip-tables/commits/58a55da60cd7564d8ee481bde908ea0166d435eb'},
#     {'sha': '29cfa4d2281b4b2304d1a825e2bf12b581930e33',
#      'author': {'email': 'andrew.underwood@workiva.com',
#       'name': 'Andrew Underwood'},
#      'message': 'Include pom in built jar',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Workiva/flip-tables/commits/29cfa4d2281b4b2304d1a825e2bf12b581930e33'},
#     {'sha': '915f2f39db2912c8867896b57a3f4df0ab0511ab',
#      'author': {'email': 'andrew.underwood@workiva.com',
#       'name': 'Andrew Underwood'},
#      'message': 'Release artifacts with versioning from git tag',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Workiva/flip-tables/commits/915f2f39db2912c8867896b57a3f4df0ab0511ab'},
#     {'sha': '1d506d0f7d2e7b69dedeec659734ede69eb118d7',
#      'author': {'email': 'andrew.underwood@workiva.com',
#       'name': 'Andrew Underwood'},
#      'message': 'Cleanup',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Workiva/flip-tables/commits/1d506d0f7d2e7b69dedeec659734ede69eb118d7'}]},
#   'public': True,
#   'created_at': '2022-06-06T15:37:29Z',
#   'org': {'id': 1087529,
#    'login': 'Workiva',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Workiva',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1087529?'}},
#  {'id': '22183786956',
#   'type': 'PullRequestReviewEvent',
#   'actor': {'id': 5915211,
#    'login': 'mike-parkhill',
#    'display_login': 'mike-parkhill',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mike-parkhill',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5915211?'},
#   'repo': {'id': 375829304,
#    'name': 'docknetwork/react-native-sdk',
#    'url': 'https://api.github.com/repos/docknetwork/react-native-sdk'},
#   'payload': {'action': 'created',
#    'review': {'id': 996803903,
#     'node_id': 'PRR_kwDOFmazOM47agU_',
#     'user': {'login': 'mike-parkhill',
#      'id': 5915211,
#      'node_id': 'MDQ6VXNlcjU5MTUyMTE=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/5915211?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/mike-parkhill',
#      'html_url': 'https://github.com/mike-parkhill',
#      'followers_url': 'https://api.github.com/users/mike-parkhill/followers',
#      'following_url': 'https://api.github.com/users/mike-parkhill/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/mike-parkhill/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/mike-parkhill/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/mike-parkhill/subscriptions',
#      'organizations_url': 'https://api.github.com/users/mike-parkhill/orgs',
#      'repos_url': 'https://api.github.com/users/mike-parkhill/repos',
#      'events_url': 'https://api.github.com/users/mike-parkhill/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/mike-parkhill/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': None,
#     'commit_id': 'fac8f1cf468462af243d9fdda1c76209d6b2dfbe',
#     'submitted_at': '2022-06-06T15:37:28Z',
#     'state': 'commented',
#     'html_url': 'https://github.com/docknetwork/react-native-sdk/pull/30#pullrequestreview-996803903',
#     'pull_request_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/pulls/30',
#     'author_association': 'CONTRIBUTOR',
#     '_links': {'html': {'href': 'https://github.com/docknetwork/react-native-sdk/pull/30#pullrequestreview-996803903'},
#      'pull_request': {'href': 'https://api.github.com/repos/docknetwork/react-native-sdk/pulls/30'}}},
#    'pull_request': {'url': 'https://api.github.com/repos/docknetwork/react-native-sdk/pulls/30',
#     'id': 959240225,
#     'node_id': 'PR_kwDOFmazOM45LNgh',
#     'html_url': 'https://github.com/docknetwork/react-native-sdk/pull/30',
#     'diff_url': 'https://github.com/docknetwork/react-native-sdk/pull/30.diff',
#     'patch_url': 'https://github.com/docknetwork/react-native-sdk/pull/30.patch',
#     'issue_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/issues/30',
#     'number': 30,
#     'state': 'open',
#     'locked': False,
#     'title': 'fixing data migration issues',
#     'user': {'login': 'maycon-mello',
#      'id': 12645078,
#      'node_id': 'MDQ6VXNlcjEyNjQ1MDc4',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/12645078?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/maycon-mello',
#      'html_url': 'https://github.com/maycon-mello',
#      'followers_url': 'https://api.github.com/users/maycon-mello/followers',
#      'following_url': 'https://api.github.com/users/maycon-mello/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/maycon-mello/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/maycon-mello/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/maycon-mello/subscriptions',
#      'organizations_url': 'https://api.github.com/users/maycon-mello/orgs',
#      'repos_url': 'https://api.github.com/users/maycon-mello/repos',
#      'events_url': 'https://api.github.com/users/maycon-mello/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/maycon-mello/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '- bump wallet-sdk packages\n- fixing issues with wallet migration\n',
#     'created_at': '2022-06-06T15:22:56Z',
#     'updated_at': '2022-06-06T15:37:28Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': 'e1cb3de7139a4dd4a5a9253c3b83a106e0c6de8f',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/pulls/30/commits',
#     'review_comments_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/pulls/30/comments',
#     'review_comment_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/issues/30/comments',
#     'statuses_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/statuses/fac8f1cf468462af243d9fdda1c76209d6b2dfbe',
#     'head': {'label': 'docknetwork:DCKA-760-wallet-accounts-and-cred-data-disapears-after-updating-wallet-155',
#      'ref': 'DCKA-760-wallet-accounts-and-cred-data-disapears-after-updating-wallet-155',
#      'sha': 'fac8f1cf468462af243d9fdda1c76209d6b2dfbe',
#      'user': {'login': 'docknetwork',
#       'id': 52467402,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjUyNDY3NDAy',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/52467402?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/docknetwork',
#       'html_url': 'https://github.com/docknetwork',
#       'followers_url': 'https://api.github.com/users/docknetwork/followers',
#       'following_url': 'https://api.github.com/users/docknetwork/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/docknetwork/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/docknetwork/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/docknetwork/subscriptions',
#       'organizations_url': 'https://api.github.com/users/docknetwork/orgs',
#       'repos_url': 'https://api.github.com/users/docknetwork/repos',
#       'events_url': 'https://api.github.com/users/docknetwork/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/docknetwork/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 375829304,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzNzU4MjkzMDQ=',
#       'name': 'react-native-sdk',
#       'full_name': 'docknetwork/react-native-sdk',
#       'private': False,
#       'owner': {'login': 'docknetwork',
#        'id': 52467402,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjUyNDY3NDAy',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/52467402?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/docknetwork',
#        'html_url': 'https://github.com/docknetwork',
#        'followers_url': 'https://api.github.com/users/docknetwork/followers',
#        'following_url': 'https://api.github.com/users/docknetwork/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/docknetwork/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/docknetwork/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/docknetwork/subscriptions',
#        'organizations_url': 'https://api.github.com/users/docknetwork/orgs',
#        'repos_url': 'https://api.github.com/users/docknetwork/repos',
#        'events_url': 'https://api.github.com/users/docknetwork/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/docknetwork/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/docknetwork/react-native-sdk',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/docknetwork/react-native-sdk',
#       'forks_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/forks',
#       'keys_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/teams',
#       'hooks_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/hooks',
#       'issue_events_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/events',
#       'assignees_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/tags',
#       'blobs_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/languages',
#       'stargazers_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/stargazers',
#       'contributors_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/contributors',
#       'subscribers_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/subscribers',
#       'subscription_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/subscription',
#       'commits_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/merges',
#       'archive_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/downloads',
#       'issues_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/deployments',
#       'created_at': '2021-06-10T21:00:59Z',
#       'updated_at': '2022-02-01T19:18:05Z',
#       'pushed_at': '2022-06-06T15:24:49Z',
#       'git_url': 'git://github.com/docknetwork/react-native-sdk.git',
#       'ssh_url': 'git@github.com:docknetwork/react-native-sdk.git',
#       'clone_url': 'https://github.com/docknetwork/react-native-sdk.git',
#       'svn_url': 'https://github.com/docknetwork/react-native-sdk',
#       'homepage': None,
#       'size': 11966,
#       'stargazers_count': 1,
#       'watchers_count': 1,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': True,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 2,
#       'watchers': 1,
#       'default_branch': 'master'}},
#     'base': {'label': 'docknetwork:master',
#      'ref': 'master',
#      'sha': 'be7c2e0eb82045bfe1263f7b4dc92f9376014db2',
#      'user': {'login': 'docknetwork',
#       'id': 52467402,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjUyNDY3NDAy',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/52467402?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/docknetwork',
#       'html_url': 'https://github.com/docknetwork',
#       'followers_url': 'https://api.github.com/users/docknetwork/followers',
#       'following_url': 'https://api.github.com/users/docknetwork/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/docknetwork/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/docknetwork/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/docknetwork/subscriptions',
#       'organizations_url': 'https://api.github.com/users/docknetwork/orgs',
#       'repos_url': 'https://api.github.com/users/docknetwork/repos',
#       'events_url': 'https://api.github.com/users/docknetwork/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/docknetwork/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 375829304,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzNzU4MjkzMDQ=',
#       'name': 'react-native-sdk',
#       'full_name': 'docknetwork/react-native-sdk',
#       'private': False,
#       'owner': {'login': 'docknetwork',
#        'id': 52467402,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjUyNDY3NDAy',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/52467402?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/docknetwork',
#        'html_url': 'https://github.com/docknetwork',
#        'followers_url': 'https://api.github.com/users/docknetwork/followers',
#        'following_url': 'https://api.github.com/users/docknetwork/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/docknetwork/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/docknetwork/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/docknetwork/subscriptions',
#        'organizations_url': 'https://api.github.com/users/docknetwork/orgs',
#        'repos_url': 'https://api.github.com/users/docknetwork/repos',
#        'events_url': 'https://api.github.com/users/docknetwork/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/docknetwork/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/docknetwork/react-native-sdk',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/docknetwork/react-native-sdk',
#       'forks_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/forks',
#       'keys_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/teams',
#       'hooks_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/hooks',
#       'issue_events_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/events',
#       'assignees_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/tags',
#       'blobs_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/languages',
#       'stargazers_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/stargazers',
#       'contributors_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/contributors',
#       'subscribers_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/subscribers',
#       'subscription_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/subscription',
#       'commits_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/merges',
#       'archive_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/downloads',
#       'issues_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/docknetwork/react-native-sdk/deployments',
#       'created_at': '2021-06-10T21:00:59Z',
#       'updated_at': '2022-02-01T19:18:05Z',
#       'pushed_at': '2022-06-06T15:24:49Z',
#       'git_url': 'git://github.com/docknetwork/react-native-sdk.git',
#       'ssh_url': 'git@github.com:docknetwork/react-native-sdk.git',
#       'clone_url': 'https://github.com/docknetwork/react-native-sdk.git',
#       'svn_url': 'https://github.com/docknetwork/react-native-sdk',
#       'homepage': None,
#       'size': 11966,
#       'stargazers_count': 1,
#       'watchers_count': 1,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': True,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 2,
#       'watchers': 1,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/docknetwork/react-native-sdk/pulls/30'},
#      'html': {'href': 'https://github.com/docknetwork/react-native-sdk/pull/30'},
#      'issue': {'href': 'https://api.github.com/repos/docknetwork/react-native-sdk/issues/30'},
#      'comments': {'href': 'https://api.github.com/repos/docknetwork/react-native-sdk/issues/30/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/docknetwork/react-native-sdk/pulls/30/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/docknetwork/react-native-sdk/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/docknetwork/react-native-sdk/pulls/30/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/docknetwork/react-native-sdk/statuses/fac8f1cf468462af243d9fdda1c76209d6b2dfbe'}},
#     'author_association': 'COLLABORATOR',
#     'auto_merge': None,
#     'active_lock_reason': None}},
#   'public': True,
#   'created_at': '2022-06-06T15:37:29Z',
#   'org': {'id': 52467402,
#    'login': 'docknetwork',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/docknetwork',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52467402?'}},
#  {'id': '22183786929',
#   'type': 'PushEvent',
#   'actor': {'id': 36922235,
#    'login': 'fabio-r-almeida',
#    'display_login': 'fabio-r-almeida',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fabio-r-almeida',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36922235?'},
#   'repo': {'id': 487551482,
#    'name': 'fabio-r-almeida/fabio-r-almeida.github.io',
#    'url': 'https://api.github.com/repos/fabio-r-almeida/fabio-r-almeida.github.io'},
#   'payload': {'push_id': 10083794393,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '27555e87d39a64c1e189f9d6da031f0abe4747c6',
#    'before': 'fbf03eb272e380172c49c74775e3141fcc100339',
#    'commits': [{'sha': '27555e87d39a64c1e189f9d6da031f0abe4747c6',
#      'author': {'email': '36922235+fabio-r-almeida@users.noreply.github.com',
#       'name': 'FabioAlmeida'},
#      'message': '.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/fabio-r-almeida/fabio-r-almeida.github.io/commits/27555e87d39a64c1e189f9d6da031f0abe4747c6'}]},
#   'public': True,
#   'created_at': '2022-06-06T15:37:29Z'},
#  {'id': '22183786914',
#   'type': 'DeleteEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 382277264,
#    'name': 'hangar18rip/bicep',
#    'url': 'https://api.github.com/repos/hangar18rip/bicep'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/src/textmate/eslint-8.16.0',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-06-06T15:37:29Z'},
#  {'id': '22183786918',
#   'type': 'PullRequestReviewCommentEvent',
#   'actor': {'id': 9087854,
#    'login': 'AA-Turner',
#    'display_login': 'AA-Turner',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AA-Turner',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9087854?'},
#   'repo': {'id': 28710753,
#    'name': 'sphinx-doc/sphinx',
#    'url': 'https://api.github.com/repos/sphinx-doc/sphinx'},
#   'payload': {'action': 'created',
#    'comment': {'url': 'https://api.github.com/repos/sphinx-doc/sphinx/pulls/comments/890279625',
#     'pull_request_review_id': 996803899,
#     'id': 890279625,
#     'node_id': 'PRRC_kwDOAbYXYc41EJbJ',
#     'diff_hunk': '@@ -1,16 +0,0 @@\n-version: 2\n-jobs:\n-  build:\n-    docker:\n-      - image: sphinxdoc/docker-ci',
#     'path': '.circleci/config.yml',
#     'position': 5,
#     'original_position': 5,
#     'commit_id': '97ec22f9d9738ab70f5793bf366ac7fbd39df99e',
#     'original_commit_id': '97ec22f9d9738ab70f5793bf366ac7fbd39df99e',
#     'user': {'login': 'AA-Turner',
#      'id': 9087854,
#      'node_id': 'MDQ6VXNlcjkwODc4NTQ=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/9087854?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/AA-Turner',
#      'html_url': 'https://github.com/AA-Turner',
#      'followers_url': 'https://api.github.com/users/AA-Turner/followers',
#      'following_url': 'https://api.github.com/users/AA-Turner/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/AA-Turner/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/AA-Turner/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/AA-Turner/subscriptions',
#      'organizations_url': 'https://api.github.com/users/AA-Turner/orgs',
#      'repos_url': 'https://api.github.com/users/AA-Turner/repos',
#      'events_url': 'https://api.github.com/users/AA-Turner/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/AA-Turner/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': "Ahh. I'll close this PR then.\r\n\r\nA",
#     'created_at': '2022-06-06T15:37:28Z',
#     'updated_at': '2022-06-06T15:37:28Z',
#     'html_url': 'https://github.com/sphinx-doc/sphinx/pull/10512#discussion_r890279625',
#     'pull_request_url': 'https://api.github.com/repos/sphinx-doc/sphinx/pulls/10512',
#     'author_association': 'COLLABORATOR',
#     '_links': {'self': {'href': 'https://api.github.com/repos/sphinx-doc/sphinx/pulls/comments/890279625'},
#      'html': {'href': 'https://github.com/sphinx-doc/sphinx/pull/10512#discussion_r890279625'},
#      'pull_request': {'href': 'https://api.github.com/repos/sphinx-doc/sphinx/pulls/10512'}},
#     'reactions': {'url': 'https://api.github.com/repos/sphinx-doc/sphinx/pulls/comments/890279625/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'start_line': None,
#     'original_start_line': None,
#     'start_side': None,
#     'line': 5,
#     'original_line': 5,
#     'side': 'LEFT',
#     'in_reply_to_id': 890278125},
#    'pull_request': {'url': 'https://api.github.com/repos/sphinx-doc/sphinx/pulls/10512',
#     'id': 956279048,
#     'node_id': 'PR_kwDOAbYXYc44_6kI',
#     'html_url': 'https://github.com/sphinx-doc/sphinx/pull/10512',
#     'diff_url': 'https://github.com/sphinx-doc/sphinx/pull/10512.diff',
#     'patch_url': 'https://github.com/sphinx-doc/sphinx/pull/10512.patch',
#     'issue_url': 'https://api.github.com/repos/sphinx-doc/sphinx/issues/10512',
#     'number': 10512,
#     'state': 'open',
#     'locked': False,
#     'title': 'Remove CircleCI',
#     'user': {'login': 'AA-Turner',
#      'id': 9087854,
#      'node_id': 'MDQ6VXNlcjkwODc4NTQ=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/9087854?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/AA-Turner',
#      'html_url': 'https://github.com/AA-Turner',
#      'followers_url': 'https://api.github.com/users/AA-Turner/followers',
#      'following_url': 'https://api.github.com/users/AA-Turner/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/AA-Turner/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/AA-Turner/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/AA-Turner/subscriptions',
#      'organizations_url': 'https://api.github.com/users/AA-Turner/orgs',
#      'repos_url': 'https://api.github.com/users/AA-Turner/repos',
#      'events_url': 'https://api.github.com/users/AA-Turner/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/AA-Turner/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'CicleCI seems to duplicate the checks on GitHub -- removing for simplicity. \r\n\r\n### Feature or Bugfix\r\n- Refactoring?\r\n\r\nA\r\n',
#     'created_at': '2022-06-02T19:32:14Z',
#     'updated_at': '2022-06-06T15:37:28Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': 'c36cec4deae8174225f33846c68c42906d549629',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 259070486,
#       'node_id': 'MDU6TGFiZWwyNTkwNzA0ODY=',
#       'url': 'https://api.github.com/repos/sphinx-doc/sphinx/labels/test',
#       'name': 'test',
#       'color': 'ffffff',
#       'default': False,
#       'description': None},
#      {'id': 835300861,
#       'node_id': 'MDU6TGFiZWw4MzUzMDA4NjE=',
#       'url': 'https://api.github.com/repos/sphinx-doc/sphinx/labels/refactoring',
#       'name': 'refactoring',
#       'color': 'ff82e3',
#       'default': False,
#       'description': None}],
#     'milestone': {'url': 'https://api.github.com/repos/sphinx-doc/sphinx/milestones/123',
#      'html_url': 'https://github.com/sphinx-doc/sphinx/milestone/123',
#      'labels_url': 'https://api.github.com/repos/sphinx-doc/sphinx/milestones/123/labels',
#      'id': 7831586,
#      'node_id': 'MI_kwDOAbYXYc4Ad4Ai',
#      'number': 123,
#      'title': '5.x',
#      'description': '',
#      'creator': {'login': 'tk0miya',
#       'id': 748828,
#       'node_id': 'MDQ6VXNlcjc0ODgyOA==',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/748828?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/tk0miya',
#       'html_url': 'https://github.com/tk0miya',
#       'followers_url': 'https://api.github.com/users/tk0miya/followers',
#       'following_url': 'https://api.github.com/users/tk0miya/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/tk0miya/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/tk0miya/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/tk0miya/subscriptions',
#       'organizations_url': 'https://api.github.com/users/tk0miya/orgs',
#       'repos_url': 'https://api.github.com/users/tk0miya/repos',
#       'events_url': 'https://api.github.com/users/tk0miya/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/tk0miya/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'open_issues': 39,
#      'closed_issues': 4,
#      'state': 'open',
#      'created_at': '2022-04-02T15:38:10Z',
#      'updated_at': '2022-06-06T15:10:59Z',
#      'due_on': None,
#      'closed_at': None},
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/sphinx-doc/sphinx/pulls/10512/commits',
#     'review_comments_url': 'https://api.github.com/repos/sphinx-doc/sphinx/pulls/10512/comments',
#     'review_comment_url': 'https://api.github.com/repos/sphinx-doc/sphinx/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/sphinx-doc/sphinx/issues/10512/comments',
#     'statuses_url': 'https://api.github.com/repos/sphinx-doc/sphinx/statuses/97ec22f9d9738ab70f5793bf366ac7fbd39df99e',
#     'head': {'label': 'AA-Turner:remove-circle-ci',
#      'ref': 'remove-circle-ci',
#      'sha': '97ec22f9d9738ab70f5793bf366ac7fbd39df99e',
#      'user': {'login': 'AA-Turner',
#       'id': 9087854,
#       'node_id': 'MDQ6VXNlcjkwODc4NTQ=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/9087854?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/AA-Turner',
#       'html_url': 'https://github.com/AA-Turner',
#       'followers_url': 'https://api.github.com/users/AA-Turner/followers',
#       'following_url': 'https://api.github.com/users/AA-Turner/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/AA-Turner/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/AA-Turner/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/AA-Turner/subscriptions',
#       'organizations_url': 'https://api.github.com/users/AA-Turner/orgs',
#       'repos_url': 'https://api.github.com/users/AA-Turner/repos',
#       'events_url': 'https://api.github.com/users/AA-Turner/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/AA-Turner/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 439743490,
#       'node_id': 'R_kgDOGjX0Ag',
#       'name': 'sphinx',
#       'full_name': 'AA-Turner/sphinx',
#       'private': False,
#       'owner': {'login': 'AA-Turner',
#        'id': 9087854,
#        'node_id': 'MDQ6VXNlcjkwODc4NTQ=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/9087854?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/AA-Turner',
#        'html_url': 'https://github.com/AA-Turner',
#        'followers_url': 'https://api.github.com/users/AA-Turner/followers',
#        'following_url': 'https://api.github.com/users/AA-Turner/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/AA-Turner/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/AA-Turner/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/AA-Turner/subscriptions',
#        'organizations_url': 'https://api.github.com/users/AA-Turner/orgs',
#        'repos_url': 'https://api.github.com/users/AA-Turner/repos',
#        'events_url': 'https://api.github.com/users/AA-Turner/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/AA-Turner/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/AA-Turner/sphinx',
#       'description': 'Main repository for the Sphinx documentation builder',
#       'fork': True,
#       'url': 'https://api.github.com/repos/AA-Turner/sphinx',
#       'forks_url': 'https://api.github.com/repos/AA-Turner/sphinx/forks',
#       'keys_url': 'https://api.github.com/repos/AA-Turner/sphinx/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/AA-Turner/sphinx/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/AA-Turner/sphinx/teams',
#       'hooks_url': 'https://api.github.com/repos/AA-Turner/sphinx/hooks',
#       'issue_events_url': 'https://api.github.com/repos/AA-Turner/sphinx/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/AA-Turner/sphinx/events',
#       'assignees_url': 'https://api.github.com/repos/AA-Turner/sphinx/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/AA-Turner/sphinx/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/AA-Turner/sphinx/tags',
#       'blobs_url': 'https://api.github.com/repos/AA-Turner/sphinx/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/AA-Turner/sphinx/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/AA-Turner/sphinx/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/AA-Turner/sphinx/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/AA-Turner/sphinx/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/AA-Turner/sphinx/languages',
#       'stargazers_url': 'https://api.github.com/repos/AA-Turner/sphinx/stargazers',
#       'contributors_url': 'https://api.github.com/repos/AA-Turner/sphinx/contributors',
#       'subscribers_url': 'https://api.github.com/repos/AA-Turner/sphinx/subscribers',
#       'subscription_url': 'https://api.github.com/repos/AA-Turner/sphinx/subscription',
#       'commits_url': 'https://api.github.com/repos/AA-Turner/sphinx/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/AA-Turner/sphinx/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/AA-Turner/sphinx/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/AA-Turner/sphinx/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/AA-Turner/sphinx/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/AA-Turner/sphinx/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/AA-Turner/sphinx/merges',
#       'archive_url': 'https://api.github.com/repos/AA-Turner/sphinx/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/AA-Turner/sphinx/downloads',
#       'issues_url': 'https://api.github.com/repos/AA-Turner/sphinx/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/AA-Turner/sphinx/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/AA-Turner/sphinx/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/AA-Turner/sphinx/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/AA-Turner/sphinx/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/AA-Turner/sphinx/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/AA-Turner/sphinx/deployments',
#       'created_at': '2021-12-19T00:32:19Z',
#       'updated_at': '2022-05-06T19:34:56Z',
#       'pushed_at': '2022-06-06T15:27:32Z',
#       'git_url': 'git://github.com/AA-Turner/sphinx.git',
#       'ssh_url': 'git@github.com:AA-Turner/sphinx.git',
#       'clone_url': 'https://github.com/AA-Turner/sphinx.git',
#       'svn_url': 'https://github.com/AA-Turner/sphinx',
#       'homepage': 'https://www.sphinx-doc.org',
#       'size': 83401,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Python',
#       'has_issues': False,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': True,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'sphinx-doc:5.x',
#      'ref': '5.x',
#      'sha': 'af425c069f6f51ba8fb3c348fd53479f0434a779',
#      'user': {'login': 'sphinx-doc',
#       'id': 9928167,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjk5MjgxNjc=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/9928167?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/sphinx-doc',
#       'html_url': 'https://github.com/sphinx-doc',
#       'followers_url': 'https://api.github.com/users/sphinx-doc/followers',
#       'following_url': 'https://api.github.com/users/sphinx-doc/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/sphinx-doc/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/sphinx-doc/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/sphinx-doc/subscriptions',
#       'organizations_url': 'https://api.github.com/users/sphinx-doc/orgs',
#       'repos_url': 'https://api.github.com/users/sphinx-doc/repos',
#       'events_url': 'https://api.github.com/users/sphinx-doc/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/sphinx-doc/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 28710753,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyODcxMDc1Mw==',
#       'name': 'sphinx',
#       'full_name': 'sphinx-doc/sphinx',
#       'private': False,
#       'owner': {'login': 'sphinx-doc',
#        'id': 9928167,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjk5MjgxNjc=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/9928167?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/sphinx-doc',
#        'html_url': 'https://github.com/sphinx-doc',
#        'followers_url': 'https://api.github.com/users/sphinx-doc/followers',
#        'following_url': 'https://api.github.com/users/sphinx-doc/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/sphinx-doc/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/sphinx-doc/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/sphinx-doc/subscriptions',
#        'organizations_url': 'https://api.github.com/users/sphinx-doc/orgs',
#        'repos_url': 'https://api.github.com/users/sphinx-doc/repos',
#        'events_url': 'https://api.github.com/users/sphinx-doc/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/sphinx-doc/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/sphinx-doc/sphinx',
#       'description': 'Main repository for the Sphinx documentation builder',
#       'fork': False,
#       'url': 'https://api.github.com/repos/sphinx-doc/sphinx',
#       'forks_url': 'https://api.github.com/repos/sphinx-doc/sphinx/forks',
#       'keys_url': 'https://api.github.com/repos/sphinx-doc/sphinx/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/sphinx-doc/sphinx/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/sphinx-doc/sphinx/teams',
# ...
#     {'sha': '852d11258dbd45107948916f0529f99dfd5b8574',
#      'author': {'email': 'jhonatan.siqueira@passeidireto.com',
#       'name': 'Jhonatan Siqueira'},
#      'message': 'teste',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/jhonsouza/rest-api-4/commits/852d11258dbd45107948916f0529f99dfd5b8574'},
#     {'sha': '995149106baefe4de13e3708bfd2a885347d4fec',
#      'author': {'email': 'jhonatan.siqueira@passeidireto.com',
#       'name': 'Jhonatan Siqueira'},
#      'message': 'teste 2',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/jhonsouza/rest-api-4/commits/995149106baefe4de13e3708bfd2a885347d4fec'},
#     {'sha': '517bd07421ce6e914ab87ebfcb031ea7fe640934',
#      'author': {'email': 'jhonatan.siqueira@passeidireto.com',
#       'name': 'Jhonatan Siqueira'},
#      'message': 'teste 3',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/jhonsouza/rest-api-4/commits/517bd07421ce6e914ab87ebfcb031ea7fe640934'},
#     {'sha': 'bf4fe1b7a76ba5b75d3b9cc1828bfc5f3f610e00',
#      'author': {'email': 'jhonatan.siqueira@passeidireto.com',
#       'name': 'Jhonatan Siqueira'},
#      'message': 'update',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/jhonsouza/rest-api-4/commits/bf4fe1b7a76ba5b75d3b9cc1828bfc5f3f610e00'},
#     {'sha': 'cc24482f4b18ca4dd0016a5cec4fb996220af909',
#      'author': {'email': '59746113+jhonsouza@users.noreply.github.com',
#       'name': 'Jhonatan Souza de Siqueira'},
#      'message': "Merge branch 'release/1.0.0' into main",
#      'distinct': False,
#      'url': 'https://api.github.com/repos/jhonsouza/rest-api-4/commits/cc24482f4b18ca4dd0016a5cec4fb996220af909'},
#     {'sha': '10f5909e7e01e8d229e3389faff537e248c6dad3',
#      'author': {'email': '59746113+jhonsouza@users.noreply.github.com',
#       'name': 'Jhonatan Souza de Siqueira'},
#      'message': 'Merge pull request #4 from jhonsouza/main\n\nupdate release',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jhonsouza/rest-api-4/commits/10f5909e7e01e8d229e3389faff537e248c6dad3'}]},
#   'public': True,
#   'created_at': '2022-06-06T15:37:28Z'},
#  {'id': '22183786529',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 40585662,
#    'login': '95-martin-orion',
#    'display_login': '95-martin-orion',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/95-martin-orion',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/40585662?'},
#   'repo': {'id': 114306758,
#    'name': 'quantumlib/Cirq',
#    'url': 'https://api.github.com/repos/quantumlib/Cirq'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/quantumlib/Cirq/issues/3556',
#     'repository_url': 'https://api.github.com/repos/quantumlib/Cirq',
#     'labels_url': 'https://api.github.com/repos/quantumlib/Cirq/issues/3556/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/quantumlib/Cirq/issues/3556/comments',
#     'events_url': 'https://api.github.com/repos/quantumlib/Cirq/issues/3556/events',
#     'html_url': 'https://github.com/quantumlib/Cirq/issues/3556',
#     'id': 753988501,
#     'node_id': 'MDU6SXNzdWU3NTM5ODg1MDE=',
#     'number': 3556,
#     'title': 'How to determine if an operation has a gate?',
#     'user': {'login': 'dabacon',
#      'id': 87974,
#      'node_id': 'MDQ6VXNlcjg3OTc0',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/87974?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dabacon',
#      'html_url': 'https://github.com/dabacon',
#      'followers_url': 'https://api.github.com/users/dabacon/followers',
#      'following_url': 'https://api.github.com/users/dabacon/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dabacon/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dabacon/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dabacon/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dabacon/orgs',
#      'repos_url': 'https://api.github.com/users/dabacon/repos',
#      'events_url': 'https://api.github.com/users/dabacon/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dabacon/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 2237625005,
#       'node_id': 'MDU6TGFiZWwyMjM3NjI1MDA1',
#       'url': 'https://api.github.com/repos/quantumlib/Cirq/labels/triage/discuss',
#       'name': 'triage/discuss',
#       'color': 'fef2c0',
#       'default': False,
#       'description': 'Needs decision / discussion, bring these up during Cirq Cynque'},
#      {'id': 2272167108,
#       'node_id': 'MDU6TGFiZWwyMjcyMTY3MTA4',
#       'url': 'https://api.github.com/repos/quantumlib/Cirq/labels/kind/bug-report',
#       'name': 'kind/bug-report',
#       'color': 'd93f0b',
#       'default': False,
#       'description': "Something doesn't seem to work."},
#      {'id': 2272172527,
#       'node_id': 'MDU6TGFiZWwyMjcyMTcyNTI3',
#       'url': 'https://api.github.com/repos/quantumlib/Cirq/labels/triage/accepted',
#       'name': 'triage/accepted',
#       'color': 'c2e0c6',
#       'default': False,
#       'description': 'there is consensus amongst maintainers that this is a real bug or a reasonable feature to add'},
#      {'id': 2272258044,
#       'node_id': 'MDU6TGFiZWwyMjcyMjU4MDQ0',
#       'url': 'https://api.github.com/repos/quantumlib/Cirq/labels/area/transformers',
#       'name': 'area/transformers',
#       'color': '1d76db',
#       'default': False,
#       'description': ''},
#      {'id': 2314513567,
#       'node_id': 'MDU6TGFiZWwyMzE0NTEzNTY3',
#       'url': 'https://api.github.com/repos/quantumlib/Cirq/labels/area/tags',
#       'name': 'area/tags',
#       'color': '1d76db',
#       'default': False,
#       'description': ''},
#      {'id': 3823793270,
#       'node_id': 'LA_kwDOBtAuxs7j6nR2',
#       'url': 'https://api.github.com/repos/quantumlib/Cirq/labels/time/before-1.0',
#       'name': 'time/before-1.0',
#       'color': '6B54E7',
#       'default': False,
#       'description': 'Should try to close before 1.0'}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 8,
#     'created_at': '2020-12-01T04:05:32Z',
#     'updated_at': '2022-06-06T15:37:27Z',
#     'closed_at': None,
#     'author_association': 'COLLABORATOR',
#     'active_lock_reason': None,
#     'body': "It used to be that you could check whether an operation had a gate using a type check\r\n`isinstance(gate_op, cirq.GateOperation)`\r\nBut if you tag an `op` it loses that signature.\r\n`isinstance(gate_op.with_tags('you are it'), cirq.GateOperation) == False`\r\n\r\nNote that there are a lot of these checks throughout Cirq that will presumably break when you tag an operation.  For example look at `cirq.EjectPhasedPaulis()`.\r\n```\r\neject = cirq.EjectPhasedPaulis()\r\nq = cirq.NamedQubit('a')\r\ncircuit = cirq.Circuit(cirq.PhasedXPowGate(phase_exponent=0.125)(q), cirq.Z(q))\r\neject.optimize_circuit(circuit)\r\nprint(circuit)\r\n```\r\ndoes the correct optimization\r\n```\r\na: ───PhX(0.625)───────\r\n```\r\nPut if you tag the Z, it doesn't do the optimization\r\n```\r\ncircuit = cirq.Circuit(cirq.PhasedXPowGate(phase_exponent=0.125)(q), cirq.Z(q).with_tags('you are it')\r\neject.optimize_circuit(circuit)\r\nprint(circuit)\r\n```\r\nprints\r\n```\r\na: ───PhX(0.125)───Z['you are it']───\r\n```",
#     'reactions': {'url': 'https://api.github.com/repos/quantumlib/Cirq/issues/3556/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/quantumlib/Cirq/issues/3556/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None},
#    'comment': {'url': 'https://api.github.com/repos/quantumlib/Cirq/issues/comments/1147589838',
#     'html_url': 'https://github.com/quantumlib/Cirq/issues/3556#issuecomment-1147589838',
#     'issue_url': 'https://api.github.com/repos/quantumlib/Cirq/issues/3556',
#     'id': 1147589838,
#     'node_id': 'IC_kwDOBtAuxs5EZtTO',
#     'user': {'login': '95-martin-orion',
#      'id': 40585662,
#      'node_id': 'MDQ6VXNlcjQwNTg1NjYy',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/40585662?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/95-martin-orion',
#      'html_url': 'https://github.com/95-martin-orion',
#      'followers_url': 'https://api.github.com/users/95-martin-orion/followers',
#      'following_url': 'https://api.github.com/users/95-martin-orion/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/95-martin-orion/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/95-martin-orion/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/95-martin-orion/subscriptions',
#      'organizations_url': 'https://api.github.com/users/95-martin-orion/orgs',
#      'repos_url': 'https://api.github.com/users/95-martin-orion/repos',
#      'events_url': 'https://api.github.com/users/95-martin-orion/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/95-martin-orion/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2022-06-06T15:37:27Z',
#     'updated_at': '2022-06-06T15:37:27Z',
#     'author_association': 'COLLABORATOR',
#     'body': "As noted on the (now closed) #3678, I've given up on `get_operator`. If there are still operation types that don't have a `gate` field we can track that here, but otherwise I think it's fine to close.",
#     'reactions': {'url': 'https://api.github.com/repos/quantumlib/Cirq/issues/comments/1147589838/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2022-06-06T15:37:28Z',
#   'org': {'id': 31279789,
#    'login': 'quantumlib',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/quantumlib',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/31279789?'}},
#  {'id': '22183786544',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 9816214,
#    'login': 'squigglybob',
#    'display_login': 'squigglybob',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/squigglybob',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9816214?'},
#   'repo': {'id': 77566278,
#    'name': 'DiscipleTools/disciple-tools-theme',
#    'url': 'https://api.github.com/repos/DiscipleTools/disciple-tools-theme'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/DiscipleTools/disciple-tools-theme/issues/1687',
#     'repository_url': 'https://api.github.com/repos/DiscipleTools/disciple-tools-theme',
#     'labels_url': 'https://api.github.com/repos/DiscipleTools/disciple-tools-theme/issues/1687/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/DiscipleTools/disciple-tools-theme/issues/1687/comments',
#     'events_url': 'https://api.github.com/repos/DiscipleTools/disciple-tools-theme/issues/1687/events',
#     'html_url': 'https://github.com/DiscipleTools/disciple-tools-theme/pull/1687',
#     'id': 1235026571,
#     'node_id': 'PR_kwDOBJ-RRs43xj3f',
#     'number': 1687,
#     'title': 'feat: create custom link field',
#     'user': {'login': 'squigglybob',
#      'id': 9816214,
#      'node_id': 'MDQ6VXNlcjk4MTYyMTQ=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/9816214?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/squigglybob',
#      'html_url': 'https://github.com/squigglybob',
#      'followers_url': 'https://api.github.com/users/squigglybob/followers',
#      'following_url': 'https://api.github.com/users/squigglybob/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/squigglybob/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/squigglybob/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/squigglybob/subscriptions',
#      'organizations_url': 'https://api.github.com/users/squigglybob/orgs',
#      'repos_url': 'https://api.github.com/users/squigglybob/repos',
#      'events_url': 'https://api.github.com/users/squigglybob/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/squigglybob/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 4,
#     'created_at': '2022-05-13T10:05:33Z',
#     'updated_at': '2022-06-06T15:37:27Z',
#     'closed_at': None,
#     'author_association': 'COLLABORATOR',
#     'active_lock_reason': None,
#     'draft': False,
#     'pull_request': {'url': 'https://api.github.com/repos/DiscipleTools/disciple-tools-theme/pulls/1687',
#      'html_url': 'https://github.com/DiscipleTools/disciple-tools-theme/pull/1687',
#      'diff_url': 'https://github.com/DiscipleTools/disciple-tools-theme/pull/1687.diff',
#      'patch_url': 'https://github.com/DiscipleTools/disciple-tools-theme/pull/1687.patch',
#      'merged_at': None},
#     'body': 'add the ui for creating and displaying link fields',
#     'reactions': {'url': 'https://api.github.com/repos/DiscipleTools/disciple-tools-theme/issues/1687/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/DiscipleTools/disciple-tools-theme/issues/1687/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None},
#    'comment': {'url': 'https://api.github.com/repos/DiscipleTools/disciple-tools-theme/issues/comments/1147589841',
#     'html_url': 'https://github.com/DiscipleTools/disciple-tools-theme/pull/1687#issuecomment-1147589841',
#     'issue_url': 'https://api.github.com/repos/DiscipleTools/disciple-tools-theme/issues/1687',
#     'id': 1147589841,
#     'node_id': 'IC_kwDOBJ-RRs5EZtTR',
#     'user': {'login': 'squigglybob',
#      'id': 9816214,
#      'node_id': 'MDQ6VXNlcjk4MTYyMTQ=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/9816214?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/squigglybob',
#      'html_url': 'https://github.com/squigglybob',
#      'followers_url': 'https://api.github.com/users/squigglybob/followers',
#      'following_url': 'https://api.github.com/users/squigglybob/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/squigglybob/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/squigglybob/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/squigglybob/subscriptions',
#      'organizations_url': 'https://api.github.com/users/squigglybob/orgs',
#      'repos_url': 'https://api.github.com/users/squigglybob/repos',
#      'events_url': 'https://api.github.com/users/squigglybob/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/squigglybob/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2022-06-06T15:37:27Z',
#     'updated_at': '2022-06-06T15:37:27Z',
#     'author_association': 'COLLABORATOR',
#     'body': '@corsacca Not sure I understand what displaying values in the list table is referring to :O(\r\ndo you mean in the field explorer?',
#     'reactions': {'url': 'https://api.github.com/repos/DiscipleTools/disciple-tools-theme/issues/comments/1147589841/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2022-06-06T15:37:28Z',
#   'org': {'id': 31960909,
#    'login': 'DiscipleTools',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/DiscipleTools',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/31960909?'}}]

# %% [markdown]
# # Gotta Catch 'Em All! Using the Pokemon API
#
# https://pokeapi.co/
#
# Nice place to start because there's no login details or credentials to fuss with
#
# For now, just want to explore grabbing the Types of different Pokemon.
#
# Useful documentation links:
# - Pokemon endpoint: https://pokeapi.co/docs/v2#pokemon
#     - `https://pokeapi.co/api/v2/pokemon/{id or name}/`
# - Type endpoint: https://pokeapi.co/docs/v2#types
#     - `https://pokeapi.co/api/v2/type/{id or name}/`

# %% [markdown]
# ### Start by exploring the response from the Pokemon endpoint
#
# Going to start with Charmander, pokemon #4, cause he's one of my favorites
#
# <img src="https://i.pinimg.com/originals/e7/0e/d0/e70ed0b54f9230c56c2e3bd2958d68a4.jpg" alt="adorable charmander found via pinterest" width=150>
#
# [Image Source](https://www.pinterest.com/pin/419045940312305352/)

# %%
# First, what endpoint url are we using?
base_poke_url = "https://pokeapi.co/api/v2/pokemon/"

# %%
# How does that need to adapt for charmander?
#char_url = f"{base_poke_url}charmander"
#Same as:
char_url = base_poke_url + "charmander"

# %%
# Check the status code, will this work?
requests.get(char_url).status_code
# Out:
# 200

# %%
# Now let's actually get the response
char_resp = requests.get(char_url).json()

# %%
# Let's check out some details about the response
char_resp.keys()
# Out:
# dict_keys(['abilities', 'base_experience', 'forms', 'game_indices', 'height', 'held_items', 'id', 'is_default', 'location_area_encounters', 'moves', 'name', 'order', 'past_types', 'species', 'sprites', 'stats', 'types', 'weight'])

# %%
char_resp['id']
# Out:
# 4

# %%
char_resp['name']
# Out:
# 'charmander'

# %%
char_resp['types'][0]['type']['name']
# Out:
# 'fire'

# %%
bulba_resp = requests.get(base_poke_url + "1").json()
bulba_resp['types']
# Out:
# [{'slot': 1,
#   'type': {'name': 'grass', 'url': 'https://pokeapi.co/api/v2/type/12/'}},
#  {'slot': 2,
#   'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}}]

# %% [markdown]
# #### Challenge!
#
# Let's write a function that, given a response from this API's pokemon endpoint, returns a list of the ID, name, primary type and secondary type for that pokemon.

# %%
def get_pokemon_details(poke_resp):
    '''
    inputs:
    poke_resp - expects json/dict
    
    outputs: 
    list of id, pokemon name, primary type and secondary type 
    '''
    poke_id = poke_resp['id']
    poke_name = poke_resp['name']
    primary_type = poke_resp['types'][0]['type']['name']
    
    if  len(poke_resp['types']) > 1:
        secondary_type = poke_resp['types'][1]['type']['name']
    else: 
        secondary_type = 'None'
        
    return [poke_id, poke_name, primary_type, secondary_type]

# %%
# Let's test our function on the 3 original starter pokemon
original_starter_ids = list(range(1,10, 3))
print(original_starter_ids)
# Out:
# [1, 4, 7]

# %%
for poke_id in original_starter_ids:
    url = f"{base_poke_url}{poke_id}/"
    resp = requests.get(url).json()
    details = get_pokemon_details(resp)
    print(details)
# Out:
# [1, 'bulbasaur', 'grass', 'poison']
# [4, 'charmander', 'fire', 'None']
# [7, 'squirtle', 'water', 'None']

# %% [markdown]
# ### Moving to Pandas
#
# Let's get all of these details for all of the original 151 pokemon! And save them to a Pandas dataframe.

# %%
# Need to import pandas
import pandas as pd

# %%
# Let's go ahead and define what our columns will be
col_names = ['id', 'name', 'primary_type', 'secondary_type']

# %%
col_names
# Out:
# ['id', 'name', 'primary_type', 'secondary_type']

# %%
# Define a list of our 151 pokemon ids
original_151 = list(range(1,152))

# %% [markdown]
# So we're going to make 151 requests... don't want to overload the API endpoint! So let's use the time library to space out our requests.

# %%
# library

# %%
import time

# %%
# Easiest way to do this will be to have a list of lists, then concat them all

# Define a blank list to capture all the pokemon details
row_list = []

# And then loop over our pokemon ids!
for poke_id in original_151:
    url = f"{base_poke_url}{poke_id}/"
    resp = requests.get(url).json()
    details = get_pokemon_details(resp)
    row_list.append(details)
    time.sleep(.5)
    
# Then, concat everything into one df
# Reference: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.append.html
poke_df = pd.concat([pd.DataFrame([i], columns = col_names) for i in row_list], ignore_index=True)

# %%
poke_df
# Out:
#       id        name primary_type secondary_type
# 0      1   bulbasaur        grass         poison
# 1      2     ivysaur        grass         poison
# 2      3    venusaur        grass         poison
# 3      4  charmander         fire           None
# 4      5  charmeleon         fire           None
# ..   ...         ...          ...            ...
# 146  147     dratini       dragon           None
# 147  148   dragonair       dragon           None
# 148  149   dragonite       dragon         flying
# 149  150      mewtwo      psychic           None
# 150  151         mew      psychic           None
#
# [151 rows x 4 columns]

# %%
# visualize it!
import matplotlib.pyplot as plt

primary_type_count = poke_df.groupby('primary_type').count()['id'].sort_values(ascending=False)

plt.figure(figsize=(10,8))
plt.bar(primary_type_count.index, primary_type_count)

plt.title("Counts of Pokemon Primary Types")
plt.ylabel("Number of Pokemon")
plt.xlabel("Primary Type")
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ![monty python gif - and now for something completely different, from giphy](https://media.giphy.com/media/xznyPebL28X5u/giphy.gif)

# %% [markdown]
# # Movie Time!
#
# Let's practice with an API that actually requires some authorization, in the form of an API Key!
#
# https://www.themoviedb.org/documentation/api

# %% [markdown]
# # **NEVER EVER PUT YOUR API KEY ON GITHUB**
#
# Either create a json file with API keys in a different directory, or create a python file with the key saved as a variable that you can call. (There are even more options than that, but these are two easily-accessible ones)

# %%
# Option 1: use a json file saved to some other folder outside your Git repo
# You can make a secrets folder on your ~ directory!
# In a new terminal window, create a file called api.json and save the path to that file

# Need to import json to do this
import json

# Quick helper function to open the json
def get_keys(path):
    with open(path) as f:
        return json.load(f)

# Using the function to open and load all keys in that file 
api_keys = get_keys("/Users/lberlin/secrets/api.json")

# Setting the first (and only) value as a variable
tmdb_key_1 = api_keys['tmdb_key']

# %%
# Option 2: use a python file that's been added to your .gitignore

# In a new terminal window, create a file called keys.py in this repo
# Save the api key as tmdb_api_key = "[key]"

from keys import tmdb_api_key

tmdb_key_2 = tmdb_api_key

# Then let's edit our .gitignore file together

# %% [markdown]
# Just as important! You may want to call the variable you've set to check that the API key is rendering correctly - but **be sure to clear the output of that cell** or else the output will show your key! And then if you push to GitHub it'll push that output to the internet which defeats the whole point of saving your key elsewhere!

# %% [markdown]
# ### And now, accessing movie data
#
# Documentation: https://developers.themoviedb.org/3

# %%
# Default URL given as an example... let's see what it is!
test_url = f"https://api.themoviedb.org/3/movie/550?api_key={tmdb_key_1}"

# %%
test_resp = requests.get(test_url).json()

# %%
test_resp.keys()

# %%
# Find similar movies to the previous id
fight_club_id = 550
similar_url = f"https://api.themoviedb.org/3/movie/{fight_club_id}/similar?api_key={tmdb_key_1}"
similar_resp = requests.get(similar_url).json()

# %%
similar_resp.keys()

# %%
# How many similar movies did it find?
similar_resp['total_results']

# %%
# but is that the length of these results?
len(similar_resp['results'])

# %%
# what's in here?
for res in similar_resp['results']:
    print(res['title'])

# %% [markdown]
# ## Level Up: Another Way to Deal with APIs
#
# Check out [Postman](https://www.getpostman.com/).

# %% [markdown]
# ## Extra Credit: Further Practice
#
# There are many ways to access data through APIs! [Sodapy](https://github.com/xmunoz/sodapy) is the Python client for the Socrata Open Data API.

# %%
# Install before running 
# !pip install sodapy

# %% [markdown]
# #### Tokenize yourself!
#
# https://dev.socrata.com/foundry/data.cityofnewyork.us/fhrw-4uyv
#
# Scroll down and click to sign up for an app token! No credit cards required!

# %%
token = '' # paste your token here 

import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofnewyork.us", token)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofnewyork.us,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("fhrw-4uyv", incident_zip = '11004', limit=1000)

# %%
type(results)

# %%
len(results)

# %%
results[0]

# %%
df_soda = pd.DataFrame(results)

print(len(df_soda))
print(df_soda.columns)
df_soda.head()

# %% [markdown]
# ## Even Further Practice
#
# https://github.com/toddmotto/public-apis
#
# Find a buddy, find a free api, get a key, and do a GET. Try to transform the response into a dataframe.
